# %% [markdown]
# <a href="https://colab.research.google.com/github/MISHTI100/Electric-Vehicle/blob/main/electric_vehicle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('electric vehicle.csv')

# %%
df
# Out:
#       sessionId  kwhTotal  dollars              created                ended  \
# 0       1366563      7.78     0.00  0014-11-18 15:40:26  0014-11-18 17:11:04
# 1       3075723      9.74     0.00  0014-11-19 17:40:26  0014-11-19 19:51:04
# 2       4228788      6.76     0.58  0014-11-21 12:05:46  0014-11-21 16:46:04
# 3       3173284      6.17     0.00  0014-12-03 19:16:12  0014-12-03 21:02:18
# 4       3266500      0.93     0.00  0014-12-11 20:56:11  0014-12-11 21:14:06
# ...         ...       ...      ...                  ...                  ...
# 3390    7021565      6.74     0.00  0015-10-01 16:31:18  0015-10-01 19:59:08
# 3391    3758092      6.86     0.00  0015-10-02 16:28:48  0015-10-02 19:27:05
# 3392    5858374      6.07     0.00  0015-09-30 16:54:22  0015-09-30 20:24:06
# 3393    2586645      5.74     0.00  0015-09-24 11:43:02  0015-09-24 13:55:12
# 3394    7860608      6.95     0.00  0015-10-01 16:43:05  0015-10-01 19:42:06
#
# ...

# %%
df.head(10)
# Out:
#    sessionId  kwhTotal  dollars              created                ended  \
# 0    1366563      7.78     0.00  0014-11-18 15:40:26  0014-11-18 17:11:04
# 1    3075723      9.74     0.00  0014-11-19 17:40:26  0014-11-19 19:51:04
# 2    4228788      6.76     0.58  0014-11-21 12:05:46  0014-11-21 16:46:04
# 3    3173284      6.17     0.00  0014-12-03 19:16:12  0014-12-03 21:02:18
# 4    3266500      0.93     0.00  0014-12-11 20:56:11  0014-12-11 21:14:06
# 5    4099366      2.14     0.00  0014-12-12 14:38:44  0014-12-12 15:04:04
# 6    5084244      0.30     0.00  0014-12-12 15:08:40  0014-12-12 15:47:04
# 7    2948436      1.82     0.00  0014-12-17 20:30:25  0014-12-17 21:31:04
# 8    3515913      0.81     0.00  0014-12-18 17:53:19  0014-12-18 18:04:04
# 9    8490014      1.98     0.00  0014-12-18 18:06:49  0014-12-18 18:30:05
#
#    startTime  endTime  chargeTimeHrs weekday platform  ...  managerVehicle  \
# 0         15       17       1.510556     Tue  android  ...               0
# ...

# %%
df.tail(10)
# Out:
#       sessionId  kwhTotal  dollars              created                ended  \
# 3385    8587381      0.02      0.0  0015-09-23 16:44:24  0015-09-23 17:11:14
# 3386    3510363      0.08      0.0  0015-09-23 19:16:39  0015-09-23 20:58:07
# 3387    9145545      0.06      0.0  0015-09-24 18:49:03  0015-09-24 20:09:06
# 3388    7948311      6.73      0.0  0015-09-29 16:37:20  0015-09-29 20:05:11
# 3389    8045573      6.56      0.0  0015-09-30 16:59:04  0015-09-30 20:27:06
# 3390    7021565      6.74      0.0  0015-10-01 16:31:18  0015-10-01 19:59:08
# 3391    3758092      6.86      0.0  0015-10-02 16:28:48  0015-10-02 19:27:05
# 3392    5858374      6.07      0.0  0015-09-30 16:54:22  0015-09-30 20:24:06
# 3393    2586645      5.74      0.0  0015-09-24 11:43:02  0015-09-24 13:55:12
# 3394    7860608      6.95      0.0  0015-10-01 16:43:05  0015-10-01 19:42:06
#
#       startTime  endTime  chargeTimeHrs weekday platform  ...  managerVehicle  \
# ...

# %%
df.dtypes
# Out:
# sessionId           int64
# kwhTotal          float64
# dollars           float64
# created            object
# ended              object
# startTime           int64
# endTime             int64
# chargeTimeHrs     float64
# weekday            object
# platform           object
# distance          float64
# userId              int64
# stationId           int64
# locationId          int64
# managerVehicle      int64
# facilityType        int64
# Mon                 int64
# Tues                int64
# Wed                 int64
# Thurs               int64
# Fri                 int64
# Sat                 int64
# Sun                 int64
# reportedZip         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sessionId       3395 non-null   int64
#  1   kwhTotal        3395 non-null   float64
#  2   dollars         3395 non-null   float64
#  3   created         3395 non-null   object
#  4   ended           3395 non-null   object
#  5   startTime       3395 non-null   int64
#  6   endTime         3395 non-null   int64
#  7   chargeTimeHrs   3395 non-null   float64
#  8   weekday         3395 non-null   object
#  9   platform        3395 non-null   object
#  10  distance        2330 non-null   float64
#  11  userId          3395 non-null   int64
#  12  stationId       3395 non-null   int64
#  13  locationId      3395 non-null   int64
#  14  managerVehicle  3395 non-null   int64
#  15  facilityType    3395 non-null   int64
#  16  Mon             3395 non-null   int64
# ...

# %%
df.describe()
# Out:
#           sessionId     kwhTotal      dollars    startTime      endTime  \
# count  3.395000e+03  3395.000000  3395.000000  3395.000000  3395.000000
# mean   5.487001e+06     5.809629     0.118268    13.743446    16.455965
# std    2.590657e+06     2.892727     0.492562     3.204370     3.406732
# min    1.004821e+06     0.000000     0.000000     0.000000     0.000000
# 25%    3.234666e+06     4.350000     0.000000    11.000000    14.000000
# 50%    5.451498e+06     6.230000     0.000000    13.000000    16.000000
# 75%    7.746644e+06     6.830000     0.000000    17.000000    20.000000
# max    9.998981e+06    23.680000     7.500000    23.000000    23.000000
#
#        chargeTimeHrs     distance        userId      stationId     locationId  \
# count    3395.000000  2330.000000  3.395000e+03    3395.000000    3395.000000
# mean        2.841488    18.652378  5.742395e+07  576789.678056  629934.460677
# std         1.507472    11.420571  2.674772e+07  257486.310402  255620.993849
# ...

# %%
from sklearn.impute import SimpleImputer
imputer_mean = SimpleImputer(missing_values = np.nan, strategy = 'mean')
df[['distance']] = imputer_mean.fit_transform(df[['distance']]).astype('object')

# %%
df.head(10)
# Out:
#    sessionId  kwhTotal  dollars              created                ended  \
# 0    1366563      7.78     0.00  0014-11-18 15:40:26  0014-11-18 17:11:04
# 1    3075723      9.74     0.00  0014-11-19 17:40:26  0014-11-19 19:51:04
# 2    4228788      6.76     0.58  0014-11-21 12:05:46  0014-11-21 16:46:04
# 3    3173284      6.17     0.00  0014-12-03 19:16:12  0014-12-03 21:02:18
# 4    3266500      0.93     0.00  0014-12-11 20:56:11  0014-12-11 21:14:06
# 5    4099366      2.14     0.00  0014-12-12 14:38:44  0014-12-12 15:04:04
# 6    5084244      0.30     0.00  0014-12-12 15:08:40  0014-12-12 15:47:04
# 7    2948436      1.82     0.00  0014-12-17 20:30:25  0014-12-17 21:31:04
# 8    3515913      0.81     0.00  0014-12-18 17:53:19  0014-12-18 18:04:04
# 9    8490014      1.98     0.00  0014-12-18 18:06:49  0014-12-18 18:30:05
#
#    startTime  endTime  chargeTimeHrs weekday platform  ... managerVehicle  \
# 0         15       17       1.510556     Tue  android  ...              0
# ...

# %%
df.tail(10)
# Out:
#       sessionId  kwhTotal  dollars              created                ended  \
# 3385    8587381      0.02      0.0  0015-09-23 16:44:24  0015-09-23 17:11:14
# 3386    3510363      0.08      0.0  0015-09-23 19:16:39  0015-09-23 20:58:07
# 3387    9145545      0.06      0.0  0015-09-24 18:49:03  0015-09-24 20:09:06
# 3388    7948311      6.73      0.0  0015-09-29 16:37:20  0015-09-29 20:05:11
# 3389    8045573      6.56      0.0  0015-09-30 16:59:04  0015-09-30 20:27:06
# 3390    7021565      6.74      0.0  0015-10-01 16:31:18  0015-10-01 19:59:08
# 3391    3758092      6.86      0.0  0015-10-02 16:28:48  0015-10-02 19:27:05
# 3392    5858374      6.07      0.0  0015-09-30 16:54:22  0015-09-30 20:24:06
# 3393    2586645      5.74      0.0  0015-09-24 11:43:02  0015-09-24 13:55:12
# 3394    7860608      6.95      0.0  0015-10-01 16:43:05  0015-10-01 19:42:06
#
#       startTime  endTime  chargeTimeHrs weekday platform  ... managerVehicle  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sessionId       3395 non-null   int64
#  1   kwhTotal        3395 non-null   float64
#  2   dollars         3395 non-null   float64
#  3   created         3395 non-null   object
#  4   ended           3395 non-null   object
#  5   startTime       3395 non-null   int64
#  6   endTime         3395 non-null   int64
#  7   chargeTimeHrs   3395 non-null   float64
#  8   weekday         3395 non-null   object
#  9   platform        3395 non-null   object
#  10  distance        3395 non-null   object
#  11  userId          3395 non-null   int64
#  12  stationId       3395 non-null   int64
#  13  locationId      3395 non-null   int64
#  14  managerVehicle  3395 non-null   int64
#  15  facilityType    3395 non-null   int64
#  16  Mon             3395 non-null   int64
# ...

# %%
data = df.drop(columns = ['created','ended','weekday','platform'])

# %%
data
# Out:
#       sessionId  kwhTotal  dollars  startTime  endTime  chargeTimeHrs  \
# 0       1366563      7.78     0.00         15       17       1.510556
# 1       3075723      9.74     0.00         17       19       2.177222
# 2       4228788      6.76     0.58         12       16       4.671667
# 3       3173284      6.17     0.00         19       21       1.768333
# 4       3266500      0.93     0.00         20       21       0.298611
# ...         ...       ...      ...        ...      ...            ...
# 3390    7021565      6.74     0.00         16       19       3.463889
# 3391    3758092      6.86     0.00         16       19       2.971389
# 3392    5858374      6.07     0.00         16       20       3.495556
# 3393    2586645      5.74     0.00         11       13       2.202778
# 3394    7860608      6.95     0.00         16       19       2.983611
#
#        distance    userId  stationId  locationId  managerVehicle  \
# ...

# %%
data.hist(figsize = (40,40))
plt.show()

# %%
y = data.iloc[:,11].values
x = data.drop(columns = data.columns[11]).values

# %%
x
# Out:
# array([[1366563, 7.78, 0.0, ..., 0, 0, 0],
#        [3075723, 9.74, 0.0, ..., 0, 0, 0],
#        [4228788, 6.76, 0.58, ..., 0, 0, 0],
#        ...,
#        [5858374, 6.07, 0.0, ..., 0, 0, 1],
#        [2586645, 5.74, 0.0, ..., 0, 0, 1],
#        [7860608, 6.95, 0.0, ..., 0, 0, 1]], dtype=object)

# %%
y
# Out:
# array([3, 3, 3, ..., 3, 2, 3])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 0)

# %%
x_train
# Out:
# array([[6887552, 6.56, 0.0, ..., 0, 0, 1],
#        [7175298, 2.96, 0.0, ..., 0, 0, 1],
#        [4068586, 3.6, 0.0, ..., 0, 0, 1],
#        ...,
#        [1383996, 6.94, 0.0, ..., 1, 0, 1],
#        [7920925, 7.02, 0.0, ..., 0, 0, 1],
#        [2139022, 6.67, 0.58, ..., 0, 0, 0]], dtype=object)

# %%
x_test
# Out:
# array([[7141257, 4.75, 0.0, ..., 0, 0, 1],
#        [1380549, 6.75, 0.0, ..., 0, 0, 1],
#        [2277153, 3.49, 0.0, ..., 0, 0, 1],
#        ...,
#        [1644680, 5.2, 0.0, ..., 0, 0, 1],
#        [1311275, 5.44, 0.0, ..., 0, 0, 1],
#        [3770628, 6.57, 0.0, ..., 0, 0, 1]], dtype=object)

# %%
y_train
# Out:
# array([3, 3, 3, ..., 3, 3, 4])

# %%
y_test
# Out:
# array([3, 3, 3, 3, 2, 3, 1, 1, 3, 3, 2, 3, 2, 2, 4, 3, 2, 3, 1, 3, 3, 3,
#        1, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 1, 1, 2, 2, 3, 3, 3, 2, 3, 1, 3,
#        3, 2, 2, 3, 3, 3, 4, 2, 3, 1, 3, 3, 1, 1, 3, 2, 3, 2, 3, 3, 4, 1,
#        1, 2, 2, 1, 3, 3, 3, 2, 4, 3, 3, 1, 2, 2, 2, 2, 4, 3, 2, 3, 2, 3,
#        3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 2, 3, 3, 2, 3, 3, 3, 3, 1, 1, 3,
#        3, 3, 1, 3, 3, 3, 1, 3, 1, 3, 3, 2, 3, 1, 1, 3, 3, 3, 3, 3, 3, 3,
#        2, 1, 3, 3, 1, 3, 2, 2, 2, 3, 2, 3, 3, 3, 3, 3, 4, 3, 2, 3, 3, 3,
#        2, 3, 1, 2, 1, 2, 2, 3, 3, 3, 3, 3, 2, 2, 2, 1, 3, 2, 2, 3, 3, 1,
#        2, 2, 3, 2, 2, 3, 2, 1, 3, 3, 2, 2, 1, 1, 3, 3, 3, 2, 3, 3, 2, 3,
#        2, 1, 2, 3, 2, 4, 3, 3, 1, 3, 3, 2, 1, 3, 2, 1, 2, 1, 3, 3, 2, 3,
#        3, 3, 3, 2, 3, 4, 2, 3, 2, 3, 2, 1, 3, 3, 2, 1, 3, 3, 3, 2, 1, 1,
#        3, 3, 3, 3, 1, 1, 3, 3, 3, 3, 3, 1, 4, 3, 2, 3, 3, 3, 1, 1, 3, 3,
#        3, 3, 2, 2, 1, 3, 2, 1, 3, 3, 2, 3, 2, 2, 3, 2, 3, 3, 2, 2, 3, 1,
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 0.52488191,  0.27768286, -0.24146957, ..., -0.14008408,
#         -0.08438159,  0.64194311],
#        [ 0.63520924, -0.99762406, -0.24146957, ..., -0.14008408,
#         -0.08438159,  0.64194311],
#        [-0.55596373, -0.77090283, -0.24146957, ..., -0.14008408,
#         -0.08438159,  0.64194311],
#        ...,
#        [-1.58528703,  0.41229859, -0.24146957, ...,  7.13857014,
#         -0.08438159,  0.64194311],
#        [ 0.92109694,  0.44063874, -0.24146957, ..., -0.14008408,
#         -0.08438159,  0.64194311],
#        [-1.29579558,  0.31665057,  1.01433546, ..., -0.14008408,
#         -0.08438159, -1.55777043]])

# %%
x_test
# Out:
# array([[ 0.69030915, -0.37553452, -0.24120381, ..., -0.1247006 ,
#         -0.08436491,  0.66808481],
#        [-1.58334774,  0.27191249, -0.24120381, ..., -0.1247006 ,
#         -0.08436491,  0.66808481],
#        [-1.22947286, -0.78342614, -0.24120381, ..., -0.1247006 ,
#         -0.08436491,  0.66808481],
#        ...,
#        [-1.47909957, -0.22985894, -0.24120381, ..., -0.1247006 ,
#         -0.08436491,  0.66808481],
#        [-1.61068905, -0.1521653 , -0.24120381, ..., -0.1247006 ,
#         -0.08436491,  0.66808481],
#        [-0.64002279,  0.21364226, -0.24120381, ..., -0.1247006 ,
#         -0.08436491,  0.66808481]])

# %%
from sklearn.tree import DecisionTreeClassifier
biased_indices = np.random.choice(np.where(y == 1)[0], size=100, replace=False)
y[biased_indices] = 1
model = DecisionTreeClassifier(criterion = 'gini',random_state = 42, max_depth = 3, min_samples_leaf=5)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report
accuracy_score(y_test,y_pred)
#make decisions or predictions
#nodes and branches
#nodes = decisions
#branches = outcomes
#leaf nodes = final outcome
# Out:
# 0.6878680800942285

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
#evaluation metric
#summary of model's performance
# Out:
#               precision    recall  f1-score   support
#
#            1       0.63      0.84      0.72       136
#            2       1.00      0.25      0.40       223
#            3       0.68      0.90      0.77       459
#            4       0.00      0.00      0.00        31
#
#     accuracy                           0.69       849
#    macro avg       0.58      0.50      0.47       849
# weighted avg       0.73      0.69      0.64       849
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#precision = accuracy of positive predictions
#recall = ability of model to find all positive instances
#f1-score = average of precision and recall
#support = number of actual occurrences of the class

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
#evaluates the performance of classification algorithm
#compares predicted labels with actual labels
# Out:
# [[114   0  22   0]
#  [ 18  56 149   0]
#  [ 45   0 414   0]
#  [  3   0  28   0]]

# %%
import seaborn as sns
mat = confusion_matrix(y_test,y_pred)
plt.subplots(figsize = (5,5))
sns.heatmap(mat.T, square = True, annot = True, fmt = 'd', cbar = False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(34.47222222222222, 0.5, 'predicted label')

# %%
model.predict([[1366563,	7.78,	0.00,	15,	17,	1.510556,	18.652378,	35897499,	582873,	461655,	0,	0,	1,	0,	0,	0,	0,	0,	0]])
# Out:
# array([3])

# %%
model.predict([[7021565,	6.74,	0.00,	16,	19,	3.463889,	13.352643,	59574735,	884707,	648339,	0,	0,	0,	0,	1,	0,	0,	0,	1]])
# Out:
# array([3])

# %%
model.predict([[2586645,	5.74,	0.00,	11,	13,	2.202778,	4.671064,	58023207,	818217,	700367,	1,	0,	0,	0,	1,	0,	0,	0,	1]])
# Out:
# array([3])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
model = RandomForestClassifier(n_estimators = 100)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
accuracy_score(y_test,y_pred)

#fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy
# Out:
# 0.9575971731448764

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           1       0.98      0.94      0.96       136\n           2       0.98      0.88      0.93       223\n           3       0.92      1.00      0.96       459\n           4       1.00      0.71      0.83        31\n\n    accuracy                           0.95       849\n   macro avg       0.97      0.88      0.92       849\nweighted avg       0.95      0.95      0.95       849\n'

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[128,   1,   7,   0],
#        [  1, 197,  25,   0],
#        [  2,   0, 457,   0],
#        [  0,   2,   7,  22]])

# %%
mat = confusion_matrix(y_test,y_pred)
plt.subplots(figsize = (5,5))
sns.heatmap(mat.T, square = True, annot = True, fmt='d', cbar = False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(34.47222222222222, 0.5, 'predicted label')

# %%
from sklearn.svm import SVC
svm = SVC(kernel = 'linear',random_state = 42)
svm.fit(x_train,y_train)
y_pred = svm.predict(x_test)
accuracy_score(y_test,y_pred)

#finds the optimal hyperplane to separate data points
# Out:
# 0.7997644287396938

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           1       0.78      0.79      0.79       136\n           2       0.89      0.57      0.69       223\n           3       0.78      0.94      0.85       459\n           4       0.88      0.48      0.62        31\n\n    accuracy                           0.80       849\n   macro avg       0.83      0.69      0.74       849\nweighted avg       0.81      0.80      0.79       849\n'

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[108,   0,  28,   0],
#        [ 14, 126,  82,   1],
#        [ 17,  11, 430,   1],
#        [  0,   5,  11,  15]])

# %%
mat = confusion_matrix(y_test,y_pred)
plt.subplots(figsize=(5,5))
sns.heatmap(mat.T,square = True, annot = True, fmt = 'd', cbar = False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(34.47222222222222, 0.5, 'predicted label')

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
model = GaussianNB()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

#Bayes theorem and probability

# %%
y_pred = model.predict(x_test)

# %%
classification_report(y_test,y_pred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 15, 120,   1,   0],
#        [  0, 223,   0,   0],
#        [  4, 442,  13,   0],
#        [  0,  29,   2,   0]])

# %%
mat = confusion_matrix(y_test,y_pred)
plt.subplots(figsize=(5,5))
sns.heatmap(mat.T,square = True, annot = True, fmt = 'd', cbar = False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(34.47222222222222, 0.5, 'predicted label')

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.2956419316843345
